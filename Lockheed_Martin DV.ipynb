# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-140b28a2-5aae-4faf-b2cb-2f6d72abf1df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-140b28a2-5aae-4faf-b2cb-2f6d72abf1df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combine aircraft and maintenance data
maint_by_type = maintenance.merge(aircraft[['Aircraft_ID', 'Type']], on='Aircraft_ID')

# Count maintenance events per aircraft type
maint_counts = maint_by_type['Type'].value_counts()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=maint_counts.index, y=maint_counts.values)
plt.title('Total Maintenance Events by Aircraft Type')
plt.ylabel('Number of Events')
plt.xlabel('Aircraft Type')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate average downtime per subsystem
avg_downtime = maintenance.groupby('Subsystem')['Downtime_Days'].mean().sort_values(ascending=False)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=avg_downtime.index, y=avg_downtime.values)
plt.title('Average Downtime (Days) per Subsystem')
plt.ylabel('Average Downtime (Days)')
plt.xlabel('Subsystem')
plt.xticks(rotation=45)
plt.show()

# %%
# Plot distribution of flight hours by aircraft type
plt.figure(figsize=(12,6))
sns.boxplot(x='Type', y='Total_Flight_Hours', data=aircraft)
plt.title('Distribution of Total Flight Hours by Aircraft Type')
plt.ylabel('Total Flight Hours')
plt.xlabel('Aircraft Type')
plt.xticks(rotation=45)
plt.show()
